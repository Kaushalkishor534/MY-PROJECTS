# %% [markdown]
# # BMI Calculator (body mass index)

# %%
name = input('Your Name :')
weight = float(input ("Enter your Weight in kgs :"))
height = float(input ("Enter Your Height in meter:"))
BMI = (weight) / (height * height)
print ('BMI :',BMI)
if BMI > 0 :
    if BMI< 16:
        print (name,' you  are ',"Severe Thinness")
    elif  BMI>16 and BMI<=17 :
        print (name,' you  are ',"Moderate Thinness")
    elif  BMI>17 and BMI<=18.5 :
        print (name,' you  are ',"Mild Thinness")
    elif  BMI>18.5 and BMI<=25 :
        print (name,' you  are ',"Normal")
    elif  BMI>25 and BMI<=30 :
        print (name,' you  are ',"Overweight")
    elif  BMI>30 and BMI<=35 :
        print (name,' you  are in ',"Obese Class I")
    elif  BMI>35 and BMI<=40 :
        print (name,' you  are in ',"Obese Class II")
    else :
        print (name,' you  are in ',"Obese Class III")
else :
    print ("Enter Valid Data")
# Out:
# Your Name : Kaushal
# Enter your Weight in kgs : 59
# Enter Your Height in meter: 165
# BMI : 0.0021671258034894397
# Kaushal  you  are  Severe Thinness

# %%
type(height)
# Out:
# float

# %%
type(BMI)
# Out:
# int

# %%
Severe Thinness	< 16
Moderate Thinness	16 - 17
Mild Thinness	17 - 18.5
Normal	18.5 - 25
Overweight	25 - 30
Obese Class I	30 - 35
Obese Class II	35 - 40
Obese Class III	> 40
# Out:
#   Cell In[15], line 1
#     Severe Thinness	< 16
#            ^
# SyntaxError: invalid syntax

# %%
if BMI > 0 :
    if BMI< 16:
        print (name,' you  are ',"Severe Thinness")
    elif  BMI>16 and BMI<=17 :
        print (name,' you  are ',"Moderate Thinness")
    elif  BMI>17 and BMI<=18.5 :
        print (name,' you  are ',"Mild Thinness")
    elif  BMI>18.5 and BMI<=25 :
        print (name,' you  are ',"Normal")
    elif  BMI>25 and BMI<=30 :
        print (name,' you  are ',"Overweight")
    elif  BMI>30 and BMI<=35 :
        print (name,' you  are in ',"Obese Class I")
    elif  BMI>35 and BMI<=40 :
        print (name,' you  are in ',"Obese Class II")
    else :
        print (name,' you  are in ',"Obese Class III")
else :
    print ("Enter Valid Data")
# Out:
# kaushal  you  are  Severe Thinness

# %%
# bmi = (weight in kgs) / (height in meters)^2
